# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)

# %%
import os

# %%
os.listdir('.')
# Out:
# [' - Copy.condarc',
#  '.astropy',
#  '.atom',
#  '.bash_history',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.dotnet',
#  '.gitconfig',
#  '.glue',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.templateengine',
#  '3D Objects',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'circumferences  of a circle and rectangle-Copy1.ipynb',
#  'circumferences  of a circle and rectangle.ipynb',
#  'Contacts',
#  'Cookies',
#  'country data assinment.ipynb',
#  'Country-data.csv',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'function practice   28-2-2021.ipynb',
#  'home work ####.ipynb',
#  'homework - Copy.ipynb',
#  'homework.ipynb',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'mm - Copy.txt',
#  'mm.txt',
#  'Music',
#  'My Documents',
#  'my file',
#  'myfile.txt',
#  'mymodule.py.pynb',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...

# %%
df = pd.read_csv('Country-data.csv')
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
df.drop('country', axis=1, inplace=True)
df
# Out:
#      child_mort  exports  health  imports  income  inflation  life_expec  \
# 0          90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1          16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2          27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3         119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4          10.3     45.5    6.03     58.9   19100       1.44        76.8
# ..          ...      ...     ...      ...     ...        ...         ...
# 162        29.2     46.6    5.25     52.7    2950       2.62        63.0
# 163        17.1     28.5    4.91     17.6   16500      45.90        75.4
# 164        23.3     72.0    6.84     80.2    4490      12.10        73.1
# 165        56.3     30.0    5.18     34.4    4480      23.60        67.5
# 166        83.1     37.0    5.89     30.9    3280      14.00        52.0
#
#      total_fer   gdpp
# 0         5.82    553
# 1         1.65   4090
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
scores = []
for i in range(1, 50):
    model = KMeans(n_clusters=i)
    model.fit(df_scaled)
    scores.append(model.inertia_)
plt.plot(range(1, 50), scores)
plt.title("Elbow Method")
plt.xlabel("num of clusters")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # clustring data with KMeans techniqe  after i know the best n_cluster which is 30 .

# %%
model = KMeans(n_clusters=30)
clusters = model.fit_predict(df_scaled)
clusters
# Out:
# array([ 8,  3, 18, 16,  3, 17,  1,  5,  5,  1,  3, 27, 21,  3,  7, 22,  7,
#        19,  7, 21, 13, 12, 17, 24,  3,  8,  4,  7,  8,  5,  7,  8,  8, 17,
#        17, 17, 19,  8, 16, 13,  8,  3,  3, 15,  5, 17, 17, 21,  3, 16, 21,
#        15,  7,  5,  5, 18, 19, 13,  5, 11,  5,  3, 25,  8,  4,  7, 20, 15,
#         5, 21, 18,  1, 11, 22,  5,  5,  1,  5, 25, 18, 19,  9, 24,  7, 21,
#         3,  3,  9,  9, 27, 15,  6,  3, 19,  8, 15, 15,  8, 23, 16,  3,  9,
#        13, 26, 13, 25,  8, 21, 12, 21, 22,  5,  8,  0, 28, 27, 21, 15,  7,
#        17, 21,  3,  5, 14,  3,  1,  4, 25, 27, 19, 13, 15,  4, 10, 15, 15,
#        12, 12,  3,  5, 18,  7, 11,  1,  5, 28, 25, 19,  7, 11, 19, 25,  3,
#        17,  7,  4,  1,  2,  5, 29, 17,  1,  7, 26,  7, 11,  8])

# %%
df['Clusters'] = clusters
df
# Out:
#      child_mort  exports  health  imports  income  inflation  life_expec  \
# 0          90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1          16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2          27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3         119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4          10.3     45.5    6.03     58.9   19100       1.44        76.8
# ..          ...      ...     ...      ...     ...        ...         ...
# 162        29.2     46.6    5.25     52.7    2950       2.62        63.0
# 163        17.1     28.5    4.91     17.6   16500      45.90        75.4
# 164        23.3     72.0    6.84     80.2    4490      12.10        73.1
# 165        56.3     30.0    5.18     34.4    4480      23.60        67.5
# 166        83.1     37.0    5.89     30.9    3280      14.00        52.0
#
#      total_fer   gdpp  Clusters
# 0         5.82    553         8
# ...

# %% [markdown]
# # using real data to test the model

# %%
data=[70 ,35 ,5.1 ,47 ,20000 ,8.5 , 65 , 3.4 ,2200 ]

# %%
model.predict(scaler.transform([data]))
# Out:
# array([21])

# %%
import joblib

# %%
joblib.dump(model, 'kmeans_model.h5')
joblib.dump(scaler, 'kmeans_scaler.h5')
# Out:
# ['kmeans_scaler.h5']
